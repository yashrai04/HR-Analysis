# %% [markdown]
# # Data Preprocessing

# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_csv('train_LZdllcl.csv')
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df2=pd.read_csv('test_2umaH9m.csv')
df2
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
print(df1["education"].isnull().sum())
# Out:
# 2409

# %%
df1=df1.dropna(subset=["education"])

# %%
print(df1["education"].isnull().sum())
# Out:
# 0

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
print(df1["no_of_trainings"].isnull().sum())
# Out:
# 0

# %%
print(df1["previous_year_rating"].isnull().sum())
# Out:
# 3739

# %%
df1.shape
# Out:
# (52399, 14)

# %%
df1["previous_year_rating"].fillna(df1["previous_year_rating"].mean(), inplace=True)
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_736\285399748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["previous_year_rating"].fillna(df1["previous_year_rating"].mean(), inplace=True)

# %%
df1["previous_year_rating"]
# Out:
# 0        5.0
# 1        5.0
# 2        3.0
# 3        1.0
# 4        3.0
#         ...
# 54802    1.0
# 54803    3.0
# 54804    2.0
# 54805    5.0
# 54807    1.0
# Name: previous_year_rating, Length: 52399, dtype: float64

# %%
print(df1["previous_year_rating"].isnull().sum())
# Out:
# 0

# %%
print(df1["length_of_service"].isnull().sum())
# Out:
# 0

# %%
print(df1["KPIs_met >80%"].isnull().sum())
# Out:
# 0

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
print(df1["awards_won?"].isnull().sum())
# Out:
# 0

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
print(df1["avg_training_score"].isnull().sum())
# Out:
# 0

# %%
for col in df1.columns:
    print(f"{col}-{df1[f'{col}'].nunique()}")
# Out:
# employee_id-52399
# department-9
# region-34
# education-3
# gender-2
# recruitment_channel-3
# no_of_trainings-10
# age-41
# previous_year_rating-6
# length_of_service-35
# KPIs_met >80%-2
# awards_won?-2
# avg_training_score-61
# is_promoted-2

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\kiit\anaconda3\lib\site-packages)

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %% [markdown]
# # EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1['department'].hist(bins=100)
plt.xlabel("Different Department")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.show()

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df1['region'].hist(bins=100)
plt.xlabel("Different Department")
plt.ylabel("Frequency")
plt.xticks(rotation=45)
plt.show()

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
edu_count=df1.groupby("education").size()
plt.pie(edu_count, labels=edu_count, autopct='%1.1f%%',startangle=90)

plt.title('Education Distribution')
plt.legend(title='Education',loc='upper right')
plt.axis('equal')
plt.show()

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
sns.lineplot(x="region",y="department", data=df1)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
df1
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
sns.barplot(x='length_of_service',y='previous_year_rating',data=df1)
# Out:
# <Axes: xlabel='length_of_service', ylabel='previous_year_rating'>

# %% [markdown]
# # Feature Engineering and Selection

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
label_encoder = LabelEncoder()
df1['department'] = label_encoder.fit_transform(df1['department'])
df1['education'] = label_encoder.fit_transform(df1['education'])
df1['gender'] = label_encoder.fit_transform(df1['gender'])
df1['recruitment_channel'] = label_encoder.fit_transform(df1['recruitment_channel'])
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_736\1856103628.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['department'] = label_encoder.fit_transform(df1['department'])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_736\1856103628.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['education'] = label_encoder.fit_transform(df1['education'])
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_736\1856103628.py:5: SettingWithCopyWarning:
# ...

# %%
#Calculate the mean promotion rate per department
df1['department_promotion'] = df1.groupby('department')['is_promoted'].transform('mean')

#Calculate the average age of promoted employees per department
df1['promotion_age_department'] = df1[df1['is_promoted'] == 1].groupby('department')['age'].transform('mean')

# Calculate the number of promotions per education level
df1['education_promotiom'] = df1.groupby('education')['is_promoted'].transform('sum')

# Calculate the percentage of promotions per gender
df1['gender_promotion'] = (df1.groupby('gender')['is_promoted'].transform('sum') / df1['is_promoted'].sum()) * 100

# Calculate the average length of service for promoted employees per department
df1['promoted_department'] = df1[df1['is_promoted'] == 1].groupby('department')['length_of_service'].transform('mean')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_736\708225550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['department_promotion'] = df1.groupby('department')['is_promoted'].transform('mean')
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_736\708225550.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['promotion_age_department'] = df1[df1['is_promoted'] == 1].groupby('department')['age'].transform('mean')
# ...

# %%
df1
# Out:
#        employee_id  department     region  education  gender  \
# 0            65438           7   region_7          2       0
# 1            65141           4  region_22          0       1
# 2             7513           7  region_19          0       1
# 3             2542           7  region_23          0       1
# 4            48945           8  region_26          0       1
# ...            ...         ...        ...        ...     ...
# 54802         6915           7  region_14          0       1
# 54803         3030           8  region_14          0       1
# 54804        74592           4  region_27          2       0
# 54805        13918           0   region_1          0       1
# 54807        51526           2  region_22          0       1
#
#        recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                        2                1   35                   5.0
# 1                        0                1   30                   5.0
# ...

# %%
region_onehot = pd.get_dummies(df1['region'], prefix='region', drop_first=True)
df1= pd.concat([df1, region_onehot], axis=1)
df1.drop('region', axis=1, inplace=True)

# %%
correlation_matrix = df1.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, annot_kws={'size': 4})
plt.title("Correlation Matrix")
plt.show()
